# %% [markdown]
# # <span style="color:blue"> <center> Multi-Linear Regression </center></span>
#
# Try to predict a continuous output from a discrete input assuming that said output is a linear combination of each feature of the datapoints.

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn import linear_model
from sklearn.metrics import  mean_squared_error
import string

# %%
def generate_linear_regression(xs, ys, test_xs, test_ys, feature_2_fit, feature_names):
    
    regressor = linear_model.LinearRegression()
    if (len(feature_2_fit) < 2):
        xi = xs[:, feature_2_fit].reshape(-1,1)
        test_xs = test_xs[:, feature_2_fit].reshape(-1,1)
    else:
        xi = xs[:, feature_2_fit]
        test_xs = test_xs[:, feature_2_fit]
        
    regressor.fit(xi, ys)
    #Training error:
    y_predicted_train = regressor.predict( xi )
    error_train = mean_squared_error( y_predicted_train, ys )
    #Testing error:
    y_predicted_test = regressor.predict( test_xs )
    error_test = mean_squared_error(y_predicted_test, test_ys)
    
    
    if (len(feature_2_fit) < 2):
        name_feature = feature_names[feature_2_fit[0]]
        plt.figure()
        plt.scatter( xi, ys, marker = '*', c = 'midnightblue')
        plt.plot( xi, y_predicted_train, color = 'crimson' )
        plt.ylabel('y')
        plt.xlabel('{}'.format(name_feature))
        plt.grid()
        plt.show()
    
    print( 'Coefficients: ', regressor.coef_, '\n Intercept: ', regressor.intercept_ )
    print('R²: ', regressor.score(xi, ys), ' MSE Training Set: ', error_train, ' MSE Test Set (Prediction): ', error_test )
    
    return regressor

# %% [markdown]
# ## <span style="color:yellow"> ----------------------------------------------------------------------------------</span>
# ## <span style="color:red"> Ex.1 - Diabetes dataset </span>
#
# Estimate how much will this disease progress after a year for a given patient, given his age, sex, body mass index, average blood pressure and 6 measurements of blood serum.

# %%
diabetes_data = pd.DataFrame.from_csv('diabetes.csv', index_col= None, sep = '\t')

ys = diabetes_data['Y']
diabetes_data = diabetes_data.drop( ['Y'], axis = 1 )
feature_names = list( diabetes_data.keys() )
diabetes_data.head()
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:1: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   """Entry point for launching an IPython kernel.
#    AGE  SEX   BMI     BP   S1     S2    S3   S4      S5  S6
# 0   59    2  32.1  101.0  157   93.2  38.0  4.0  4.8598  87
# 1   48    1  21.6   87.0  183  103.2  70.0  3.0  3.8918  69
# 2   72    2  30.5   93.0  156   93.6  41.0  4.0  4.6728  85
# 3   24    1  25.3   84.0  198  131.4  40.0  5.0  4.8903  89
# 4   50    1  23.0  101.0  192  125.4  52.0  4.0  4.2905  80

# %%
train_xs, test_xs, train_ys, test_ys = train_test_split(diabetes_data, ys, test_size = 0.3, random_state = 42)


print("Train set: ", train_xs.shape, " Test set: ", test_xs.shape)
xs = np.array( train_xs )
ys = np.array( train_ys )
test_xs = np.array( test_xs )
test_ys = np.array( test_ys )
# Out:
# Train set:  (309, 10)  Test set:  (133, 10)

# %%
for some_feature in range( len(feature_names) ):
    feature_2_fit = [some_feature]
    fitted_predictor = generate_linear_regression(xs, ys, test_xs, test_ys, feature_2_fit, feature_names)
# Out:
# Coefficients:  [1.1753968]
#  Intercept:  96.51007445991348
# R²:  0.03639799111001608  MSE Training Set:  5924.496728561793  MSE Test Set (Prediction):  5256.092886182665
# Coefficients:  [0.54760904]
#  Intercept:  153.0965627363644
# R²:  1.2156567231969007e-05  MSE Training Set:  6148.207094175328  MSE Test Set (Prediction):  5427.258712456058
# Coefficients:  [10.65330269]
#  Intercept:  -129.94726984405622
# R²:  0.3657651200418852  MSE Training Set:  3899.45479231627  MSE Test Set (Prediction):  3884.936720961031
# Coefficients:  [2.51649326]
#  Intercept:  -85.19367226957283
# R²:  0.19959342860924134  MSE Training Set:  4921.125184438375  MSE Test Set (Prediction):  4436.942407955592
# Coefficients:  [0.42012248]
#  Intercept:  73.96543323130744
# R²:  0.034881702917677226  MSE Training Set:  5933.81929571316  MSE Test Set (Prediction):  5051.229980166963
# Coefficients:  [0.40730579]
#  Intercept:  106.60838306758998
# ...

# %%
feature_2_fit = list(range( len(feature_names) ))
fitted_predictor = generate_linear_regression(xs, ys, test_xs, test_ys, feature_2_fit, feature_names)
# Out:
# Coefficients:  [  0.10626633 -24.94631999   5.88808437   1.33719761  -1.24105398
#    0.79346065   0.44604644  10.6288242   60.09633769   0.17138672]
#  Intercept:  -316.2885807533931
# R²:  0.5244124363545944  MSE Training Set:  2924.0463790726394  MSE Test Set (Prediction):  2821.750981001312
